# %% [markdown]
# <a href="https://colab.research.google.com/github/gopalkalpande/Practice-AI/blob/master/stock_rnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/xuhuanvc/stock-rnn.git
# Out:
# Cloning into 'stock-rnn'...
# remote: Enumerating objects: 21, done.
# remote: Total 21 (delta 0), reused 0 (delta 0), pack-reused 21
# Unpacking objects: 100% (21/21), done.

# %%
ls
# Out:
# sample_data/  stock-rnn/

# %%
# !python3 stock-rnn/data_cleaning.py INFY
# Out:
# INFY Download Complete

# %%
# !python3 /content/drive/My Drive/abc/stock-rnn/main.py train INFY LSTM True
# Out:
# epoch [0] finished, Loss Sum: 0.218529
# epoch [1] finished, Loss Sum: 0.211453
# epoch [2] finished, Loss Sum: 0.207984
# epoch [3] finished, Loss Sum: 0.207537
# epoch [4] finished, Loss Sum: 0.206756
# epoch [5] finished, Loss Sum: 0.206366
# epoch [6] finished, Loss Sum: 0.206042
# epoch [7] finished, Loss Sum: 0.205804
# epoch [8] finished, Loss Sum: 0.205470
# epoch [9] finished, Loss Sum: 0.205291
# epoch [10] finished, Loss Sum: 0.205135
# epoch [11] finished, Loss Sum: 0.205013
# epoch [12] finished, Loss Sum: 0.204684
# epoch [13] finished, Loss Sum: 0.204806
# epoch [14] finished, Loss Sum: 0.204616
# epoch [15] finished, Loss Sum: 0.204444
# epoch [16] finished, Loss Sum: 0.204351
# epoch [17] finished, Loss Sum: 0.204140
# epoch [18] finished, Loss Sum: 0.203985
# epoch [19] finished, Loss Sum: 0.204041
# epoch [20] finished, Loss Sum: 0.204061
# epoch [21] finished, Loss Sum: 0.203773
# epoch [22] finished, Loss Sum: 0.203553
# epoch [23] finished, Loss Sum: 0.203601
# ...

# %%
# !python3 stock-rnn/main.py test INFY LSTM
# Out:
# 0.005827127519296482
# <Figure size 640x480 with 1 Axes>

# %%
# !ls
# Out:
# INFY.csv  LSTM.model  sample_data  stock-rnn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os 
from google.colab import files

# %%
# !ls '/content/drive/My Drive/abc/'

# %%
# !ls
# Out:
# drive  INFY.csv  LSTM.model  sample_data  stock-rnn

# %%
import shutil
shutil.move('/content/stock-rnn','/content/drive/My Drive/abc/')
# Out:
# '/content/drive/My Drive/abc/stock-rnn'

# %%
shutil.move('/content/LSTM.model','/content/drive/My Drive/abc/')
# Out:
# '/content/drive/My Drive/abc/LSTM.model'

# %%
# !python3 '/content/drive/My Drive/abc/stock-rnn/main.py' train INFY LSTM True
# Out:
# epoch [0] finished, Loss Sum: 0.231990
# epoch [1] finished, Loss Sum: 0.210740
# epoch [2] finished, Loss Sum: 0.209166
# epoch [3] finished, Loss Sum: 0.207934
# epoch [4] finished, Loss Sum: 0.207825
# epoch [5] finished, Loss Sum: 0.206886
# epoch [6] finished, Loss Sum: 0.206165
# epoch [7] finished, Loss Sum: 0.206193
# epoch [8] finished, Loss Sum: 0.205832
# epoch [9] finished, Loss Sum: 0.205607
# epoch [10] finished, Loss Sum: 0.205502
# epoch [11] finished, Loss Sum: 0.205160
# epoch [12] finished, Loss Sum: 0.204923
# epoch [13] finished, Loss Sum: 0.205071
# epoch [14] finished, Loss Sum: 0.204599
# epoch [15] finished, Loss Sum: 0.204751
# epoch [16] finished, Loss Sum: 0.204421
# epoch [17] finished, Loss Sum: 0.204151
# epoch [18] finished, Loss Sum: 0.203859
# epoch [19] finished, Loss Sum: 0.203972
# epoch [20] finished, Loss Sum: 0.204287
# epoch [21] finished, Loss Sum: 0.203988
# epoch [22] finished, Loss Sum: 0.204092
# epoch [23] finished, Loss Sum: 0.203481
# ...

# %%
# !python3 '/content/drive/My Drive/abc/stock-rnn/main.py' test INFY LSTM True
# Out:
# 0.005328416315023787
# <Figure size 640x480 with 1 Axes>
